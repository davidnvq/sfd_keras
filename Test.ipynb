# %%
import numpy as np
import cv2
from skimage import io

count = 0
Path = '/home/ubuntu/Datasets/AFW/testimages/'

f = open('sfd_afw_dets.txt', 'wt')
for Name in open('AFW/afw_img_list.txt'):
    Image_Path = Path + Name[:-1] + '.jpg'
    image = io.imread(Image_Path)
    heigh = image.shape[0]
    width = image.shape[1]
    print(heigh, width)
    print(image.shape)
    io.imshow(image)
    im_shrink = 640.0 / max(image.shape[0], image.shape[1])
    image = cv2.resize(image, None, None, fx=im_shrink, fy=im_shrink, interpolation=cv2.INTER_LINEAR)
    print("After", image.shape)

    count += 1
    if count > 0:
        break
# Out:
# 800 600
# (800, 600, 3)
# After (640, 480, 3)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
io.imshow(image)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
scales=[0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05]
for s in scales:
    print(s*300)
# Out:
# 30.0
# 60.0
# 111.0
# 162.0
# 213.0
# 264.0
# 315.0

# %%
sizes = [16, 32, 64, 128, 256, 512]
for s in sizes:
    print("%2.2f, " % (s/640), end="")
# Out:
# 0.03, 0.05, 0.10, 0.20, 0.40, 0.80,
